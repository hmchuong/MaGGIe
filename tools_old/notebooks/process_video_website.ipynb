# %%
import cv2
import numpy as np
import os
from scipy.ndimage import label as scipy_label

# %% [markdown]
# # 3_pexels-cottonbro-5329478_2160p

# %%
def resize_padding(image, size=(1920,1080)):
    """
    Resize and pad an image to a given size
    """
    h, w = image.shape[:2]
    height_ratio = size[1] / h
    width_ratio = size[0] / w
    ratio = min(height_ratio, width_ratio)
    new_h = int(h * ratio)
    new_w = int(w * ratio)
    image = cv2.resize(image, (new_w, new_h))
    delta_w = size[0] - new_w
    delta_h = size[1] - new_h
    top, bottom = delta_h//2, delta_h-(delta_h//2)
    left, right = delta_w//2, delta_w-(delta_w//2)
    color = [0, 0, 0]
    # copy make border
    new_image = cv2.copyMakeBorder(image, top, bottom, left, right, cv2.BORDER_CONSTANT, value=color)
    return new_image

def postprocess(mask):
    regions, n_regions = scipy_label(mask > 0.1)
    if n_regions > 1:
        max_area = 0
        all_areas = np.zeros((n_regions + 1,))
        for i in range(n_regions):
            all_areas[i+1] = (regions == (i+1)).sum()
            max_area = max(max_area, all_areas[i+1])
        
        if max_area == 0:
            return
        
        if max_area * 1.0 / mask.size < 0.01:
            mask[:] = 0
            return

        # Get location of areas
        max_area_id = all_areas.argmax()
        largest_mask = regions == max_area_id

        # Remove noise
        for i in range(n_regions):
            if i + 1 == max_area_id: continue
            object_mask = regions == (i+1)
            if all_areas[i+1] < max_area * 0.1:
                mask[object_mask] = 0

# %%
# Prepare video with each mask overlayed
video_name = "3_pexels-cottonbro-5329478_2160p"
data_dir = "/home/chuongh/vm2m/data/vis/real_qual"
outdir = "/home/chuongh/vm2m/data/vis/website"

frame_names = sorted(os.listdir(os.path.join(data_dir, "images", video_name)))

colors = [(255, 0, 255), (255, 255, 0), (0, 165, 255), (255, 255, 255)]
for frame_name in frame_names:
    if int(frame_name.replace(".jpg", "")) < 130 or int(frame_name.replace(".jpg", "")) > 270:
        continue
    frame = cv2.imread(os.path.join(data_dir, "images", video_name, frame_name))
    # load all masks
    mask_names = os.listdir(os.path.join(data_dir, "masks", video_name, frame_name.replace(".jpg", "")))
    mask_names = sorted(mask_names)
    all_overlays = []
    
    for i, mask_name in enumerate(mask_names):
        mask = cv2.imread(os.path.join(data_dir, "masks", video_name, frame_name.replace(".jpg", ""), mask_name), cv2.IMREAD_GRAYSCALE)
        color = colors[i]
        color = np.array(color)[None, None]
        mask = mask[:, :, None]
        mask = (mask > 0) * color
        overlay = frame.copy()
        overlay[mask > 0] = mask[mask > 0] * 0.5 + overlay[mask > 0] * 0.5
        all_overlays.append(overlay)
    all_overlays = np.concatenate(all_overlays, axis=1)
    all_overlays = resize_padding(all_overlays)

    out_path = os.path.join(outdir, video_name, "video", frame_name)
    os.makedirs(os.path.dirname(out_path), exist_ok=True)
    cv2.imwrite(out_path, all_overlays)

# %%
def process_frames(frame_names, video_name, lower, upper, subdir, outdir):
    for frame_name in frame_names:
        if int(frame_name.replace(".jpg", "")) < lower or int(frame_name.replace(".jpg", "")) > upper:
            continue
        frame = cv2.imread(os.path.join(data_dir, "images", video_name, frame_name))
        # load all masks
        mask_names = os.listdir(os.path.join(data_dir, subdir, video_name, frame_name.replace(".jpg", "")))
        mask_names = sorted(mask_names)
        all_overlays = []
        
        for i, mask_name in enumerate(mask_names):
            mask = cv2.imread(os.path.join(data_dir, subdir, video_name, frame_name.replace(".jpg", ""), mask_name), cv2.IMREAD_GRAYSCALE)
            mask = mask / 255.0
            postprocess(mask)
            mask = mask[:, :, None]
            green = np.zeros_like(frame)
            green[:, :, 1] = 255
            overlay = frame * mask + green * (1.0 - mask)
            all_overlays.append(overlay)
        all_overlays = np.concatenate(all_overlays, axis=1)
        all_overlays = resize_padding(all_overlays)

        out_path = os.path.join(outdir, video_name, subdir, frame_name)
        os.makedirs(os.path.dirname(out_path), exist_ok=True)
        cv2.imwrite(out_path, all_overlays)
# InstMatt

# %%
process_frames(frame_names, video_name, 130, 270, "instmatt", outdir)

# %%
process_frames(frame_names, video_name, 130, 270, "sparsemat_hr", outdir)

# %%
process_frames(frame_names, video_name, 130, 270, "mgm_single_tcvom", outdir)

# %%
process_frames(frame_names, video_name, 130, 270, "mgm_stacked_tcvom", outdir)

# %%
process_frames(frame_names, video_name, 130, 270, "ours_tokens", outdir)

# %% [markdown]
# # 2_pexels-artem-podrez-6003997_2160p

# %%
# Prepare video with each mask overlayed
video_name = "2_pexels-artem-podrez-6003997_2160p"
data_dir = "/home/chuongh/vm2m/data/vis/real_qual"
outdir = "/home/chuongh/vm2m/data/vis/website"

frame_names = sorted(os.listdir(os.path.join(data_dir, "images", video_name)))

colors = [(255, 0, 255), (255, 255, 0), (0, 165, 255), (255, 255, 255)]
for frame_name in frame_names:
    if int(frame_name.replace(".jpg", "")) < 0 or int(frame_name.replace(".jpg", "")) > 175:
        continue
    frame = cv2.imread(os.path.join(data_dir, "images", video_name, frame_name))
    # load all masks
    mask_names = os.listdir(os.path.join(data_dir, "masks", video_name, frame_name.replace(".jpg", "")))
    mask_names = sorted(mask_names)
    all_overlays = []
    
    for i, mask_name in enumerate(mask_names):
        mask = cv2.imread(os.path.join(data_dir, "masks", video_name, frame_name.replace(".jpg", ""), mask_name), cv2.IMREAD_GRAYSCALE)
        color = colors[i]
        color = np.array(color)[None, None]
        mask = mask[:, :, None]
        mask = (mask > 0) * color
        overlay = frame.copy()
        overlay[mask > 0] = mask[mask > 0] * 0.7 + overlay[mask > 0] * 0.3
        all_overlays.append(overlay)
    all_overlays = np.concatenate(all_overlays, axis=1)
    all_overlays = resize_padding(all_overlays)

    out_path = os.path.join(outdir, video_name, "video", frame_name)
    os.makedirs(os.path.dirname(out_path), exist_ok=True)
    cv2.imwrite(out_path, all_overlays)

# %%
process_frames(frame_names, video_name, 0, 175, "instmatt", outdir)

# %%
process_frames(frame_names, video_name, 0, 175, "sparsemat_hr", outdir)

# %%
process_frames(frame_names, video_name, 0, 175, "mgm_single_tcvom", outdir)

# %%
process_frames(frame_names, video_name, 0, 175, "mgm_stacked_tcvom", outdir)

# %%
process_frames(frame_names, video_name, 0, 175, "ours_tokens", outdir)

# %%
for subdir in ['video', 'instmatt', 'sparsemat_hr', 'mgm_single_tcvom', 'mgm_stacked_tcvom', 'ours_tokens']:
    input = os.path.join(outdir, video_name, subdir)
    # !ffmpeg -y -framerate 3 -pattern_type glob -i "{input}/*.jpg" -c:v libx264 -vf "pad=ceil(iw/2)*2:ceil(ih/2)*2" -pix_fmt yuv420p {input}.mp4

# %% [markdown]
# # 3_production_id_4122569_2160p

# %%
# Prepare video with each mask overlayed
video_name = "3_production_id_4122569_2160p"
data_dir = "/home/chuongh/vm2m/data/vis/real_qual"
outdir = "/home/chuongh/vm2m/data/vis/website"

frame_names = sorted(os.listdir(os.path.join(data_dir, "images", video_name)))

colors = [(255, 0, 255), (255, 255, 0), (0, 165, 255), (255, 255, 255)]
for frame_name in frame_names:
    if int(frame_name.replace(".jpg", "")) < 0 or int(frame_name.replace(".jpg", "")) > 120:
        continue
    frame = cv2.imread(os.path.join(data_dir, "images", video_name, frame_name))
    # load all masks
    mask_names = os.listdir(os.path.join(data_dir, "masks", video_name, frame_name.replace(".jpg", "")))
    mask_names = sorted(mask_names)
    all_overlays = []
    
    for i, mask_name in enumerate(mask_names):
        mask = cv2.imread(os.path.join(data_dir, "masks", video_name, frame_name.replace(".jpg", ""), mask_name), cv2.IMREAD_GRAYSCALE)
        color = colors[i]
        color = np.array(color)[None, None]
        mask = mask[:, :, None]
        mask = (mask > 0) * color
        frame[mask > 0] = mask[mask > 0] * 0.7 + frame[mask > 0] * 0.3
    #     all_overlays.append(overlay)
    # all_overlays = np.concatenate(all_overlays, axis=1)
    all_overlays = resize_padding(frame)

    out_path = os.path.join(outdir, video_name, "video", frame_name)
    os.makedirs(os.path.dirname(out_path), exist_ok=True)
    cv2.imwrite(out_path, all_overlays)

# %%
crop_sizes = [[800, 1770], [200, 1080], [800, 1920]]
def process_frames_with_crops(frame_names, video_name, lower, upper, subdir, outdir, mask_names, crop_sizes):
    for frame_name in frame_names:
        if int(frame_name.replace(".jpg", "")) < lower or int(frame_name.replace(".jpg", "")) > upper:
            continue
        frame = cv2.imread(os.path.join(data_dir, "images", video_name, frame_name))
        frame = frame[:, 590:]
        # load all masks
        # mask_names = os.listdir(os.path.join(data_dir, subdir, video_name, frame_name.replace(".jpg", "")))
        # mask_names = sorted(mask_names)
        all_overlays = []
        
        for i, mask_name in enumerate(mask_names):
            mask = cv2.imread(os.path.join(data_dir, subdir, video_name, frame_name.replace(".jpg", ""), mask_name), cv2.IMREAD_GRAYSCALE)
            mask = mask / 255.0
            mask = mask[:, 590:]
            postprocess(mask)
            mask = mask[:, :, None]
            green = np.zeros_like(frame)
            green[:, :, 1] = 255
            overlay = frame * mask + green * (1.0 - mask)
            overlay = resize_padding(overlay)
            crop_size = crop_sizes[i]
            overlay = overlay[:, crop_size[0]:crop_size[1]]
            all_overlays.append(overlay)
        all_overlays = np.concatenate(all_overlays, axis=1)
        all_overlays = resize_padding(all_overlays)

        out_path = os.path.join(outdir, video_name, subdir, frame_name)
        os.makedirs(os.path.dirname(out_path), exist_ok=True)
        cv2.imwrite(out_path, all_overlays)
# InstMatt

# %%
process_frames_with_crops(frame_names, video_name, 0, 120, "instmatt", outdir, ["00.png", "01.png", "02.png"], crop_sizes)

# %%
process_frames_with_crops(frame_names, video_name, 0, 120, "sparsemat_hr", outdir, ["00.png", "01.png", "02.png"], crop_sizes)

# %%
process_frames_with_crops(frame_names, video_name, 0, 120, "mgm_single_tcvom", outdir, ["00.png", "01.png", "02.png"], crop_sizes)

# %%
process_frames_with_crops(frame_names, video_name, 0, 120, "mgm_stacked_tcvom", outdir, ["00.png", "01.png", "02.png"], crop_sizes)

# %%
process_frames_with_crops(frame_names, video_name, 0, 120, "ours_ss", outdir, ["00.png", "01.png", "02.png"], crop_sizes)

# %%
for subdir in ['video', 'instmatt', 'sparsemat_hr', 'mgm_single_tcvom', 'mgm_stacked_tcvom', 'ours_ss']:
    input = os.path.join(outdir, video_name, subdir)
    # !ffmpeg -y -framerate 3 -pattern_type glob -i "{input}/*.jpg" -c:v libx264 -vf "pad=ceil(iw/2)*2:ceil(ih/2)*2" -pix_fmt yuv420p {input}.mp4
# Out:
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/home/chuongh/vm2m/data/vis/website/3_production_id_4122569_2160p/video/*.jpg':
#   Duration: 00:00:08.33, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 1920x1080 [SAR 1:1 DAR 16:9], 3 fps, 3 tbr, 3 tbn, 3 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [swscaler @ 0x5642036b8a80] deprecated pixel format used, make sure you did set range correctly
# [libx264 @ 0x5642034cc900] using SAR=1/1
# [libx264 @ 0x5642034cc900] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x5642034cc900] profile High, level 4.0, 4:2:0, 8-bit
# [libx264 @ 0x5642034cc900] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=34 lookahead_threads=5 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=3 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/home/chuongh/vm2m/data/vis/website/3_production_id_4122569_2160p/video.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1920x1080 [SAR 1:1 DAR 16:9], q=-1--1, 3 fps, 12288 tbn, 3 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   25 fps=0.0 q=-1.0 Lsize=    3038kB time=00:00:07.33 bitrate=3393.4kbits/s speed=7.57x
# video:3037kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.038399%
# [libx264 @ 0x5642034cc900] frame I:1     Avg QP:16.97  size:309926
# [libx264 @ 0x5642034cc900] frame P:7     Avg QP:17.36  size:180669
# [libx264 @ 0x5642034cc900] frame B:17    Avg QP:18.98  size: 90246
# [libx264 @ 0x5642034cc900] consecutive B-frames:  8.0%  0.0% 12.0% 80.0%
# [libx264 @ 0x5642034cc900] mb I  I16..4:  1.5% 86.4% 12.1%
# [libx264 @ 0x5642034cc900] mb P  I16..4:  1.0% 31.0%  4.8%  P16..4: 25.3% 24.5% 12.6%  0.0%  0.0%    skip: 0.8%
# [libx264 @ 0x5642034cc900] mb B  I16..4:  0.1%  3.1%  1.1%  B16..8: 38.4% 20.7%  7.2%  direct:12.9%  skip:16.3%  L0:43.3% L1:38.3% BI:18.4%
# [libx264 @ 0x5642034cc900] 8x8 transform intra:82.6% inter:64.4%
# [libx264 @ 0x5642034cc900] coded y,uvDC,uvAC intra: 92.5% 99.2% 93.4% inter: 48.5% 66.6% 28.2%
# [libx264 @ 0x5642034cc900] i16 v,h,dc,p:  6%  9%  6% 79%
# [libx264 @ 0x5642034cc900] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 17% 15% 16%  6%  9%  9%  9%  9%  9%
# [libx264 @ 0x5642034cc900] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 22% 15% 12%  7% 11% 10% 10%  7%  6%
# [libx264 @ 0x5642034cc900] i8c dc,h,v,p: 49% 19% 19% 13%
# [libx264 @ 0x5642034cc900] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x5642034cc900] ref P L0: 56.0% 14.7% 19.4%  9.9%
# [libx264 @ 0x5642034cc900] ref B L0: 88.1%  9.1%  2.8%
# [libx264 @ 0x5642034cc900] ref B L1: 97.2%  2.8%
# [libx264 @ 0x5642034cc900] kb/s:2984.45
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/home/chuongh/vm2m/data/vis/website/3_production_id_4122569_2160p/instmatt/*.jpg':
#   Duration: 00:00:08.33, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 1920x1080 [SAR 1:1 DAR 16:9], 3 fps, 3 tbr, 3 tbn, 3 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [swscaler @ 0x55af8b6cd5c0] deprecated pixel format used, make sure you did set range correctly
# [libx264 @ 0x55af8b62eb40] using SAR=1/1
# [libx264 @ 0x55af8b62eb40] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55af8b62eb40] profile High, level 4.0, 4:2:0, 8-bit
# [libx264 @ 0x55af8b62eb40] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=34 lookahead_threads=5 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=3 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/home/chuongh/vm2m/data/vis/website/3_production_id_4122569_2160p/instmatt.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1920x1080 [SAR 1:1 DAR 16:9], q=-1--1, 3 fps, 12288 tbn, 3 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   25 fps=0.0 q=-1.0 Lsize=    1204kB time=00:00:07.33 bitrate=1344.4kbits/s speed=12.3x
# video:1202kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.095026%
# [libx264 @ 0x55af8b62eb40] frame I:1     Avg QP: 9.67  size:135533
# [libx264 @ 0x55af8b62eb40] frame P:6     Avg QP:14.34  size: 81168
# [libx264 @ 0x55af8b62eb40] frame B:18    Avg QP:15.90  size: 33779
# [libx264 @ 0x55af8b62eb40] consecutive B-frames:  4.0%  0.0%  0.0% 96.0%
# [libx264 @ 0x55af8b62eb40] mb I  I16..4: 55.4% 38.5%  6.1%
# [libx264 @ 0x55af8b62eb40] mb P  I16..4:  1.2%  9.9%  1.4%  P16..4:  7.9%  7.9%  5.1%  0.0%  0.0%    skip:66.5%
# [libx264 @ 0x55af8b62eb40] mb B  I16..4:  0.2%  0.9%  0.3%  B16..8: 14.1%  6.6%  2.2%  direct: 3.8%  skip:71.8%  L0:35.6% L1:34.5% BI:29.9%
# [libx264 @ 0x55af8b62eb40] 8x8 transform intra:56.9% inter:55.6%
# [libx264 @ 0x55af8b62eb40] coded y,uvDC,uvAC intra: 50.5% 54.8% 45.3% inter: 12.9% 16.0% 9.5%
# [libx264 @ 0x55af8b62eb40] i16 v,h,dc,p: 88%  9%  3%  0%
# [libx264 @ 0x55af8b62eb40] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 20% 10% 23%  5%  9%  9%  8%  7%  8%
# [libx264 @ 0x55af8b62eb40] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 16% 15% 13%  8% 12% 11%  9%  8%  7%
# [libx264 @ 0x55af8b62eb40] i8c dc,h,v,p: 63% 15% 16%  6%
# [libx264 @ 0x55af8b62eb40] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55af8b62eb40] ref P L0: 49.3% 18.2% 22.2% 10.3%
# [libx264 @ 0x55af8b62eb40] ref B L0: 88.6%  8.9%  2.5%
# [libx264 @ 0x55af8b62eb40] ref B L1: 94.9%  5.1%
# [libx264 @ 0x55af8b62eb40] kb/s:1181.34
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/home/chuongh/vm2m/data/vis/website/3_production_id_4122569_2160p/sparsemat_hr/*.jpg':
#   Duration: 00:00:08.33, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 1920x1080 [SAR 1:1 DAR 16:9], 3 fps, 3 tbr, 3 tbn, 3 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [swscaler @ 0x561168803d40] deprecated pixel format used, make sure you did set range correctly
# [libx264 @ 0x5611687620c0] using SAR=1/1
# [libx264 @ 0x5611687620c0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x5611687620c0] profile High, level 4.0, 4:2:0, 8-bit
# [libx264 @ 0x5611687620c0] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=34 lookahead_threads=5 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=3 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/home/chuongh/vm2m/data/vis/website/3_production_id_4122569_2160p/sparsemat_hr.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1920x1080 [SAR 1:1 DAR 16:9], q=-1--1, 3 fps, 12288 tbn, 3 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   25 fps=0.0 q=-1.0 Lsize=    1259kB time=00:00:07.33 bitrate=1406.6kbits/s speed=12.2x
# video:1258kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.090823%
# [libx264 @ 0x5611687620c0] frame I:1     Avg QP:10.41  size:134445
# [libx264 @ 0x5611687620c0] frame P:6     Avg QP:16.10  size: 83035
# [libx264 @ 0x5611687620c0] frame B:18    Avg QP:15.34  size: 36383
# [libx264 @ 0x5611687620c0] consecutive B-frames:  4.0%  0.0%  0.0% 96.0%
# [libx264 @ 0x5611687620c0] mb I  I16..4: 51.3% 42.9%  5.8%
# [libx264 @ 0x5611687620c0] mb P  I16..4:  1.0% 10.2%  1.5%  P16..4:  7.9%  7.7%  5.0%  0.0%  0.0%    skip:66.7%
# [libx264 @ 0x5611687620c0] mb B  I16..4:  0.2%  1.1%  0.4%  B16..8: 13.9%  6.6%  2.4%  direct: 3.7%  skip:71.8%  L0:36.1% L1:34.9% BI:29.0%
# [libx264 @ 0x5611687620c0] 8x8 transform intra:59.7% inter:54.2%
# [libx264 @ 0x5611687620c0] coded y,uvDC,uvAC intra: 51.0% 55.7% 45.7% inter: 12.7% 15.2% 9.5%
# [libx264 @ 0x5611687620c0] i16 v,h,dc,p: 87%  9%  3%  1%
# [libx264 @ 0x5611687620c0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 21%  9% 25%  5%  9%  9%  8%  6%  7%
# [libx264 @ 0x5611687620c0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 18% 15% 15%  7% 11% 11%  9%  8%  7%
# [libx264 @ 0x5611687620c0] i8c dc,h,v,p: 61% 16% 17%  6%
# [libx264 @ 0x5611687620c0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x5611687620c0] ref P L0: 48.8% 19.0% 21.4% 10.7%
# [libx264 @ 0x5611687620c0] ref B L0: 88.1%  9.2%  2.6%
# [libx264 @ 0x5611687620c0] ref B L1: 94.5%  5.5%
# [libx264 @ 0x5611687620c0] kb/s:1236.05
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/home/chuongh/vm2m/data/vis/website/3_production_id_4122569_2160p/mgm_single_tcvom/*.jpg':
#   Duration: 00:00:08.33, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 1920x1080 [SAR 1:1 DAR 16:9], 3 fps, 3 tbr, 3 tbn, 3 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [swscaler @ 0x55d204dd8440] deprecated pixel format used, make sure you did set range correctly
# [libx264 @ 0x55d204d37040] using SAR=1/1
# [libx264 @ 0x55d204d37040] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55d204d37040] profile High, level 4.0, 4:2:0, 8-bit
# [libx264 @ 0x55d204d37040] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=34 lookahead_threads=5 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=3 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/home/chuongh/vm2m/data/vis/website/3_production_id_4122569_2160p/mgm_single_tcvom.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1920x1080 [SAR 1:1 DAR 16:9], q=-1--1, 3 fps, 12288 tbn, 3 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   25 fps=0.0 q=-1.0 Lsize=    1214kB time=00:00:07.33 bitrate=1355.9kbits/s speed=12.4x
# video:1213kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.094220%
# [libx264 @ 0x55d204d37040] frame I:1     Avg QP:10.12  size:134635
# [libx264 @ 0x55d204d37040] frame P:6     Avg QP:15.00  size: 81140
# [libx264 @ 0x55d204d37040] frame B:18    Avg QP:15.49  size: 34424
# [libx264 @ 0x55d204d37040] consecutive B-frames:  4.0%  0.0%  0.0% 96.0%
# [libx264 @ 0x55d204d37040] mb I  I16..4: 53.0% 41.1%  5.9%
# [libx264 @ 0x55d204d37040] mb P  I16..4:  1.3% 10.0%  1.5%  P16..4:  7.9%  7.8%  5.2%  0.0%  0.0%    skip:66.3%
# [libx264 @ 0x55d204d37040] mb B  I16..4:  0.2%  1.0%  0.3%  B16..8: 14.0%  6.7%  2.2%  direct: 3.7%  skip:71.8%  L0:35.8% L1:34.5% BI:29.7%
# [libx264 @ 0x55d204d37040] 8x8 transform intra:58.3% inter:54.9%
# [libx264 @ 0x55d204d37040] coded y,uvDC,uvAC intra: 50.8% 55.7% 45.7% inter: 12.6% 15.7% 9.6%
# [libx264 @ 0x55d204d37040] i16 v,h,dc,p: 87%  9%  3%  1%
# [libx264 @ 0x55d204d37040] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 19%  9% 26%  6%  9%  9%  8%  7%  8%
# [libx264 @ 0x55d204d37040] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 17% 15% 13%  8% 12% 11%  9%  8%  7%
# [libx264 @ 0x55d204d37040] i8c dc,h,v,p: 62% 15% 16%  6%
# [libx264 @ 0x55d204d37040] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55d204d37040] ref P L0: 50.1% 18.5% 20.7% 10.6%
# [libx264 @ 0x55d204d37040] ref B L0: 88.7%  8.6%  2.7%
# [libx264 @ 0x55d204d37040] ref B L1: 94.7%  5.3%
# [libx264 @ 0x55d204d37040] kb/s:1191.46
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/home/chuongh/vm2m/data/vis/website/3_production_id_4122569_2160p/mgm_stacked_tcvom/*.jpg':
#   Duration: 00:00:08.33, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 1920x1080 [SAR 1:1 DAR 16:9], 3 fps, 3 tbr, 3 tbn, 3 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [swscaler @ 0x55ca24d68540] deprecated pixel format used, make sure you did set range correctly
# [libx264 @ 0x55ca24cc7040] using SAR=1/1
# [libx264 @ 0x55ca24cc7040] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55ca24cc7040] profile High, level 4.0, 4:2:0, 8-bit
# [libx264 @ 0x55ca24cc7040] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=34 lookahead_threads=5 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=3 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/home/chuongh/vm2m/data/vis/website/3_production_id_4122569_2160p/mgm_stacked_tcvom.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1920x1080 [SAR 1:1 DAR 16:9], q=-1--1, 3 fps, 12288 tbn, 3 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   25 fps=0.0 q=-1.0 Lsize=    1221kB time=00:00:07.33 bitrate=1363.7kbits/s speed=  12x
# video:1220kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.093680%
# [libx264 @ 0x55ca24cc7040] frame I:1     Avg QP:10.55  size:134823
# [libx264 @ 0x55ca24cc7040] frame P:6     Avg QP:15.88  size: 81416
# [libx264 @ 0x55ca24cc7040] frame B:18    Avg QP:15.83  size: 34719
# [libx264 @ 0x55ca24cc7040] consecutive B-frames:  4.0%  0.0%  0.0% 96.0%
# [libx264 @ 0x55ca24cc7040] mb I  I16..4: 49.7% 44.4%  5.9%
# [libx264 @ 0x55ca24cc7040] mb P  I16..4:  1.1% 10.0%  1.5%  P16..4:  7.6%  7.7%  5.3%  0.0%  0.0%    skip:66.7%
# [libx264 @ 0x55ca24cc7040] mb B  I16..4:  0.2%  1.0%  0.3%  B16..8: 14.0%  6.6%  2.3%  direct: 3.7%  skip:71.8%  L0:36.3% L1:34.4% BI:29.3%
# [libx264 @ 0x55ca24cc7040] 8x8 transform intra:60.0% inter:54.4%
# [libx264 @ 0x55ca24cc7040] coded y,uvDC,uvAC intra: 50.3% 54.8% 44.8% inter: 12.7% 15.7% 9.6%
# [libx264 @ 0x55ca24cc7040] i16 v,h,dc,p: 86% 10%  3%  1%
# [libx264 @ 0x55ca24cc7040] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 22%  9% 25%  5%  9%  8%  8%  6%  7%
# [libx264 @ 0x55ca24cc7040] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 17% 16% 14%  8% 11% 10%  9%  8%  7%
# [libx264 @ 0x55ca24cc7040] i8c dc,h,v,p: 62% 15% 17%  6%
# [libx264 @ 0x55ca24cc7040] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55ca24cc7040] ref P L0: 49.3% 18.5% 22.0% 10.3%
# [libx264 @ 0x55ca24cc7040] ref B L0: 88.3%  8.8%  2.9%
# [libx264 @ 0x55ca24cc7040] ref B L1: 95.0%  5.0%
# [libx264 @ 0x55ca24cc7040] kb/s:1198.33
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/home/chuongh/vm2m/data/vis/website/3_production_id_4122569_2160p/ours_ss/*.jpg':
#   Duration: 00:00:08.33, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 1920x1080 [SAR 1:1 DAR 16:9], 3 fps, 3 tbr, 3 tbn, 3 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [swscaler @ 0x5627f8da3280] deprecated pixel format used, make sure you did set range correctly
# [libx264 @ 0x5627f8d03b40] using SAR=1/1
# [libx264 @ 0x5627f8d03b40] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x5627f8d03b40] profile High, level 4.0, 4:2:0, 8-bit
# [libx264 @ 0x5627f8d03b40] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=34 lookahead_threads=5 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=3 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/home/chuongh/vm2m/data/vis/website/3_production_id_4122569_2160p/ours_ss.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1920x1080 [SAR 1:1 DAR 16:9], q=-1--1, 3 fps, 12288 tbn, 3 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   25 fps=0.0 q=-1.0 Lsize=    1229kB time=00:00:07.33 bitrate=1372.9kbits/s speed=11.8x
# video:1228kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.093051%
# [libx264 @ 0x5627f8d03b40] frame I:1     Avg QP:10.41  size:136711
# [libx264 @ 0x5627f8d03b40] frame P:6     Avg QP:15.28  size: 82138
# [libx264 @ 0x5627f8d03b40] frame B:18    Avg QP:15.80  size: 34842
# [libx264 @ 0x5627f8d03b40] consecutive B-frames:  4.0%  0.0%  0.0% 96.0%
# [libx264 @ 0x5627f8d03b40] mb I  I16..4: 50.5% 43.4%  6.1%
# [libx264 @ 0x5627f8d03b40] mb P  I16..4:  1.0% 10.3%  1.4%  P16..4:  7.8%  7.6%  5.3%  0.0%  0.0%    skip:66.6%
# [libx264 @ 0x5627f8d03b40] mb B  I16..4:  0.2%  1.0%  0.3%  B16..8: 14.1%  6.8%  2.2%  direct: 3.6%  skip:71.8%  L0:35.8% L1:34.6% BI:29.6%
# [libx264 @ 0x5627f8d03b40] 8x8 transform intra:60.3% inter:54.7%
# [libx264 @ 0x5627f8d03b40] coded y,uvDC,uvAC intra: 51.0% 55.4% 45.5% inter: 12.6% 15.6% 9.7%
# [libx264 @ 0x5627f8d03b40] i16 v,h,dc,p: 88%  8%  3%  1%
# [libx264 @ 0x5627f8d03b40] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 22%  9% 25%  5%  9%  9%  8%  6%  7%
# [libx264 @ 0x5627f8d03b40] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 18% 14% 14%  8% 12% 10%  9%  8%  7%
# [libx264 @ 0x5627f8d03b40] i8c dc,h,v,p: 62% 15% 17%  6%
# [libx264 @ 0x5627f8d03b40] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x5627f8d03b40] ref P L0: 49.5% 18.3% 22.0% 10.2%
# [libx264 @ 0x5627f8d03b40] ref B L0: 88.5%  8.7%  2.7%
# [libx264 @ 0x5627f8d03b40] ref B L1: 94.6%  5.4%
# [libx264 @ 0x5627f8d03b40] kb/s:1206.43

# %% [markdown]
# # 6_production_id_4880458_2160p

# %%
# Prepare video with each mask overlayed
video_name = "6_production_id_4880458_2160p"
data_dir = "/home/chuongh/vm2m/data/vis/real_qual"
outdir = "/home/chuongh/vm2m/data/vis/website"
mask_names = ["00.png", "02.png", "05.png", "01.png"]

frame_names = sorted(os.listdir(os.path.join(data_dir, "images", video_name)))

colors = [(255, 0, 255), (255, 255, 0), (0, 165, 255), (255, 255, 255)]
for frame_name in frame_names:
    if int(frame_name.replace(".jpg", "")) < 0 or int(frame_name.replace(".jpg", "")) > 120:
        continue
    frame = cv2.imread(os.path.join(data_dir, "images", video_name, frame_name))
    frame = frame[:, 590:]
    # load all masks
    all_overlays = []
    
    for i, mask_name in enumerate(mask_names):
        mask = cv2.imread(os.path.join(data_dir, "masks", video_name, frame_name.replace(".jpg", ""), mask_name), cv2.IMREAD_GRAYSCALE)
        color = colors[i]
        color = np.array(color)[None, None]
        mask = mask[:, 590:, None]
        mask = (mask > 0) * color
        frame[mask > 0] = mask[mask > 0] * 0.7 + frame[mask > 0] * 0.3
    #     all_overlays.append(overlay)
    # all_overlays = np.concatenate(all_overlays, axis=1)
    all_overlays = resize_padding(frame)

    out_path = os.path.join(outdir, video_name, "video", frame_name)
    os.makedirs(os.path.dirname(out_path), exist_ok=True)
    cv2.imwrite(out_path, all_overlays)

# %%
crop_sizes = [[250, 555], [435, 915], [755, 1285], [1120, 1672]]
process_frames_with_crops(frame_names, video_name, 0, 120, "instmatt", outdir, mask_names, crop_sizes)

# %%
process_frames_with_crops(frame_names, video_name, 0, 120, "sparsemat_hr", outdir, mask_names, crop_sizes)

# %%
process_frames_with_crops(frame_names, video_name, 0, 120, "mgm_single_tcvom", outdir, mask_names, crop_sizes)

# %%
process_frames_with_crops(frame_names, video_name, 0, 120, "mgm_stacked_tcvom", outdir, mask_names, crop_sizes)

# %%
process_frames_with_crops(frame_names, video_name, 0, 120, "ours_tokens", outdir, mask_names, crop_sizes)

# %%
for subdir in ['video', 'instmatt', 'sparsemat_hr', 'mgm_single_tcvom', 'mgm_stacked_tcvom', 'ours_tokens']:
    input = os.path.join(outdir, video_name, subdir)
    # !ffmpeg -y -framerate 3 -pattern_type glob -i "{input}/*.jpg" -c:v libx264 -vf "pad=ceil(iw/2)*2:ceil(ih/2)*2" -pix_fmt yuv420p {input}.mp4
# Out:
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/home/chuongh/vm2m/data/vis/website/6_production_id_4880458_2160p/video/*.jpg':
#   Duration: 00:00:08.33, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 1920x1080 [SAR 1:1 DAR 16:9], 3 fps, 3 tbr, 3 tbn, 3 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [swscaler @ 0x564c9b365fc0] deprecated pixel format used, make sure you did set range correctly
# [libx264 @ 0x564c9b2cab40] using SAR=1/1
# [libx264 @ 0x564c9b2cab40] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x564c9b2cab40] profile High, level 4.0, 4:2:0, 8-bit
# [libx264 @ 0x564c9b2cab40] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=34 lookahead_threads=5 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=3 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/home/chuongh/vm2m/data/vis/website/6_production_id_4880458_2160p/video.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1920x1080 [SAR 1:1 DAR 16:9], q=-1--1, 3 fps, 12288 tbn, 3 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   25 fps=0.0 q=-1.0 Lsize=    1056kB time=00:00:07.33 bitrate=1179.9kbits/s speed=10.5x
# video:1055kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.108294%
# [libx264 @ 0x564c9b2cab40] frame I:1     Avg QP:15.96  size:111676
# [libx264 @ 0x564c9b2cab40] frame P:6     Avg QP:16.05  size: 70389
# [libx264 @ 0x564c9b2cab40] frame B:18    Avg QP:17.01  size: 30317
# [libx264 @ 0x564c9b2cab40] consecutive B-frames:  4.0%  0.0%  0.0% 96.0%
# [libx264 @ 0x564c9b2cab40] mb I  I16..4:  9.8% 73.8% 16.3%
# [libx264 @ 0x564c9b2cab40] mb P  I16..4:  2.9% 15.5%  3.2%  P16..4: 24.1% 17.5%  8.3%  0.0%  0.0%    skip:28.4%
# [libx264 @ 0x564c9b2cab40] mb B  I16..4:  0.7%  1.7%  0.4%  B16..8: 30.4% 13.7%  2.7%  direct: 5.7%  skip:44.8%  L0:44.3% L1:42.1% BI:13.6%
# [libx264 @ 0x564c9b2cab40] 8x8 transform intra:70.6% inter:70.0%
# [libx264 @ 0x564c9b2cab40] coded y,uvDC,uvAC intra: 49.7% 69.4% 50.2% inter: 17.4% 28.1% 9.6%
# [libx264 @ 0x564c9b2cab40] i16 v,h,dc,p: 41% 32% 11% 16%
# [libx264 @ 0x564c9b2cab40] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 25% 19% 32%  3%  4%  4%  4%  4%  4%
# [libx264 @ 0x564c9b2cab40] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 34% 21% 18%  4%  6%  6%  4%  4%  3%
# [libx264 @ 0x564c9b2cab40] i8c dc,h,v,p: 55% 20% 18%  6%
# [libx264 @ 0x564c9b2cab40] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x564c9b2cab40] ref P L0: 57.0%  7.8% 20.6% 14.5%
# [libx264 @ 0x564c9b2cab40] ref B L0: 85.6% 11.1%  3.3%
# [libx264 @ 0x564c9b2cab40] ref B L1: 94.0%  6.0%
# [libx264 @ 0x564c9b2cab40] kb/s:1036.53
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/home/chuongh/vm2m/data/vis/website/6_production_id_4880458_2160p/instmatt/*.jpg':
#   Duration: 00:00:08.33, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 1920x1080 [SAR 1:1 DAR 16:9], 3 fps, 3 tbr, 3 tbn, 3 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [swscaler @ 0x563109ff9380] deprecated pixel format used, make sure you did set range correctly
# [libx264 @ 0x563109f5eb40] using SAR=1/1
# [libx264 @ 0x563109f5eb40] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x563109f5eb40] profile High, level 4.0, 4:2:0, 8-bit
# [libx264 @ 0x563109f5eb40] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=34 lookahead_threads=5 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=3 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/home/chuongh/vm2m/data/vis/website/6_production_id_4880458_2160p/instmatt.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1920x1080 [SAR 1:1 DAR 16:9], q=-1--1, 3 fps, 12288 tbn, 3 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   25 fps=0.0 q=-1.0 Lsize=     923kB time=00:00:07.33 bitrate=1030.9kbits/s speed=11.7x
# video:922kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.122261%
# [libx264 @ 0x563109f5eb40] frame I:1     Avg QP:10.16  size:111946
# [libx264 @ 0x563109f5eb40] frame P:6     Avg QP:13.24  size: 67219
# [libx264 @ 0x563109f5eb40] frame B:18    Avg QP:16.55  size: 23775
# [libx264 @ 0x563109f5eb40] consecutive B-frames:  4.0%  0.0%  0.0% 96.0%
# [libx264 @ 0x563109f5eb40] mb I  I16..4: 48.6% 41.2% 10.1%
# [libx264 @ 0x563109f5eb40] mb P  I16..4:  1.7%  9.3%  1.6%  P16..4: 12.9% 12.9%  7.1%  0.0%  0.0%    skip:54.5%
# [libx264 @ 0x563109f5eb40] mb B  I16..4:  0.1%  0.9%  0.2%  B16..8: 20.6%  8.7%  2.1%  direct: 4.3%  skip:63.1%  L0:36.6% L1:37.2% BI:26.2%
# [libx264 @ 0x563109f5eb40] 8x8 transform intra:57.1% inter:59.0%
# [libx264 @ 0x563109f5eb40] coded y,uvDC,uvAC intra: 51.4% 54.5% 43.2% inter: 15.5% 20.2% 8.0%
# [libx264 @ 0x563109f5eb40] i16 v,h,dc,p: 94%  2%  3%  1%
# [libx264 @ 0x563109f5eb40] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 30% 10% 24%  4%  6%  8%  5%  8%  5%
# [libx264 @ 0x563109f5eb40] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 33% 12% 15%  5%  9% 10%  6%  7%  4%
# [libx264 @ 0x563109f5eb40] i8c dc,h,v,p: 60% 11% 23%  5%
# [libx264 @ 0x563109f5eb40] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x563109f5eb40] ref P L0: 53.9% 17.5% 20.1%  8.5%
# [libx264 @ 0x563109f5eb40] ref B L0: 90.2%  8.0%  1.8%
# [libx264 @ 0x563109f5eb40] ref B L1: 97.4%  2.6%
# [libx264 @ 0x563109f5eb40] kb/s:905.48
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/home/chuongh/vm2m/data/vis/website/6_production_id_4880458_2160p/sparsemat_hr/*.jpg':
#   Duration: 00:00:08.33, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 1920x1080 [SAR 1:1 DAR 16:9], 3 fps, 3 tbr, 3 tbn, 3 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [swscaler @ 0x55a8cf37b780] deprecated pixel format used, make sure you did set range correctly
# [libx264 @ 0x55a8cf2dd0c0] using SAR=1/1
# [libx264 @ 0x55a8cf2dd0c0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55a8cf2dd0c0] profile High, level 4.0, 4:2:0, 8-bit
# [libx264 @ 0x55a8cf2dd0c0] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=34 lookahead_threads=5 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=3 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/home/chuongh/vm2m/data/vis/website/6_production_id_4880458_2160p/sparsemat_hr.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1920x1080 [SAR 1:1 DAR 16:9], q=-1--1, 3 fps, 12288 tbn, 3 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   25 fps=0.0 q=-1.0 Lsize=     968kB time=00:00:07.33 bitrate=1081.5kbits/s speed=10.8x
# video:967kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.116539%
# [libx264 @ 0x55a8cf2dd0c0] frame I:1     Avg QP: 9.94  size:113585
# [libx264 @ 0x55a8cf2dd0c0] frame P:6     Avg QP:13.22  size: 69328
# [libx264 @ 0x55a8cf2dd0c0] frame B:18    Avg QP:16.60  size: 25556
# [libx264 @ 0x55a8cf2dd0c0] consecutive B-frames:  4.0%  0.0%  0.0% 96.0%
# [libx264 @ 0x55a8cf2dd0c0] mb I  I16..4: 49.4% 39.6% 10.9%
# [libx264 @ 0x55a8cf2dd0c0] mb P  I16..4:  1.8%  9.4%  1.9%  P16..4: 12.9% 12.9%  7.1%  0.0%  0.0%    skip:54.1%
# [libx264 @ 0x55a8cf2dd0c0] mb B  I16..4:  0.2%  1.0%  0.3%  B16..8: 20.6%  8.6%  2.2%  direct: 3.8%  skip:63.3%  L0:37.3% L1:37.7% BI:25.0%
# [libx264 @ 0x55a8cf2dd0c0] 8x8 transform intra:55.5% inter:58.6%
# [libx264 @ 0x55a8cf2dd0c0] coded y,uvDC,uvAC intra: 51.5% 57.0% 45.3% inter: 14.7% 19.9% 8.6%
# [libx264 @ 0x55a8cf2dd0c0] i16 v,h,dc,p: 93%  2%  3%  1%
# [libx264 @ 0x55a8cf2dd0c0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 30% 10% 22%  4%  6%  8%  5%  8%  6%
# [libx264 @ 0x55a8cf2dd0c0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 33% 11% 15%  5%  9% 10%  6%  7%  4%
# [libx264 @ 0x55a8cf2dd0c0] i8c dc,h,v,p: 59% 11% 24%  5%
# [libx264 @ 0x55a8cf2dd0c0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55a8cf2dd0c0] ref P L0: 53.7% 17.7% 19.6%  9.0%
# [libx264 @ 0x55a8cf2dd0c0] ref B L0: 90.3%  8.0%  1.6%
# [libx264 @ 0x55a8cf2dd0c0] ref B L1: 97.0%  3.0%
# [libx264 @ 0x55a8cf2dd0c0] kb/s:949.97
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/home/chuongh/vm2m/data/vis/website/6_production_id_4880458_2160p/mgm_single_tcvom/*.jpg':
#   Duration: 00:00:08.33, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 1920x1080 [SAR 1:1 DAR 16:9], 3 fps, 3 tbr, 3 tbn, 3 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [swscaler @ 0x55713cdc0700] deprecated pixel format used, make sure you did set range correctly
# [libx264 @ 0x55713cd22040] using SAR=1/1
# [libx264 @ 0x55713cd22040] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55713cd22040] profile High, level 4.0, 4:2:0, 8-bit
# [libx264 @ 0x55713cd22040] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=34 lookahead_threads=5 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=3 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/home/chuongh/vm2m/data/vis/website/6_production_id_4880458_2160p/mgm_single_tcvom.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1920x1080 [SAR 1:1 DAR 16:9], q=-1--1, 3 fps, 12288 tbn, 3 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   25 fps=0.0 q=-1.0 Lsize=     952kB time=00:00:07.33 bitrate=1063.2kbits/s speed=11.4x
# video:951kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.118551%
# [libx264 @ 0x55713cd22040] frame I:1     Avg QP: 9.56  size:114448
# [libx264 @ 0x55713cd22040] frame P:6     Avg QP:12.98  size: 69107
# [libx264 @ 0x55713cd22040] frame B:18    Avg QP:16.31  size: 24648
# [libx264 @ 0x55713cd22040] consecutive B-frames:  4.0%  0.0%  0.0% 96.0%
# [libx264 @ 0x55713cd22040] mb I  I16..4: 51.2% 38.5% 10.4%
# [libx264 @ 0x55713cd22040] mb P  I16..4:  1.9% 10.0%  1.7%  P16..4: 13.2% 13.0%  7.2%  0.0%  0.0%    skip:53.0%
# [libx264 @ 0x55713cd22040] mb B  I16..4:  0.2%  1.1%  0.3%  B16..8: 21.0%  8.6%  2.2%  direct: 4.2%  skip:62.3%  L0:37.1% L1:37.3% BI:25.6%
# [libx264 @ 0x55713cd22040] 8x8 transform intra:56.0% inter:59.5%
# [libx264 @ 0x55713cd22040] coded y,uvDC,uvAC intra: 52.1% 58.2% 46.8% inter: 15.3% 20.6% 8.4%
# [libx264 @ 0x55713cd22040] i16 v,h,dc,p: 93%  3%  3%  1%
# [libx264 @ 0x55713cd22040] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 29% 11% 23%  4%  6%  8%  5%  8%  5%
# [libx264 @ 0x55713cd22040] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 33% 12% 15%  5%  9% 10%  6%  7%  3%
# [libx264 @ 0x55713cd22040] i8c dc,h,v,p: 58% 12% 24%  6%
# [libx264 @ 0x55713cd22040] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55713cd22040] ref P L0: 54.3% 17.7% 19.4%  8.7%
# [libx264 @ 0x55713cd22040] ref B L0: 89.7%  8.5%  1.7%
# [libx264 @ 0x55713cd22040] ref B L1: 97.4%  2.6%
# [libx264 @ 0x55713cd22040] kb/s:933.84
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/home/chuongh/vm2m/data/vis/website/6_production_id_4880458_2160p/mgm_stacked_tcvom/*.jpg':
#   Duration: 00:00:08.33, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 1920x1080 [SAR 1:1 DAR 16:9], 3 fps, 3 tbr, 3 tbn, 3 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [swscaler @ 0x55d0359b7880] deprecated pixel format used, make sure you did set range correctly
# [libx264 @ 0x55d03591a040] using SAR=1/1
# [libx264 @ 0x55d03591a040] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55d03591a040] profile High, level 4.0, 4:2:0, 8-bit
# [libx264 @ 0x55d03591a040] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=34 lookahead_threads=5 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=3 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/home/chuongh/vm2m/data/vis/website/6_production_id_4880458_2160p/mgm_stacked_tcvom.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1920x1080 [SAR 1:1 DAR 16:9], q=-1--1, 3 fps, 12288 tbn, 3 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   25 fps=0.0 q=-1.0 Lsize=     942kB time=00:00:07.33 bitrate=1051.8kbits/s speed=11.6x
# video:940kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.119829%
# [libx264 @ 0x55d03591a040] frame I:1     Avg QP: 9.73  size:113147
# [libx264 @ 0x55d03591a040] frame P:6     Avg QP:13.26  size: 68507
# [libx264 @ 0x55d03591a040] frame B:18    Avg QP:16.64  size: 24343
# [libx264 @ 0x55d03591a040] consecutive B-frames:  4.0%  0.0%  0.0% 96.0%
# [libx264 @ 0x55d03591a040] mb I  I16..4: 50.4% 39.1% 10.5%
# [libx264 @ 0x55d03591a040] mb P  I16..4:  1.7%  9.6%  1.8%  P16..4: 12.9% 13.0%  7.0%  0.0%  0.0%    skip:54.0%
# [libx264 @ 0x55d03591a040] mb B  I16..4:  0.2%  0.9%  0.3%  B16..8: 20.7%  8.6%  2.1%  direct: 4.0%  skip:63.3%  L0:37.0% L1:37.2% BI:25.8%
# [libx264 @ 0x55d03591a040] 8x8 transform intra:55.7% inter:59.0%
# [libx264 @ 0x55d03591a040] coded y,uvDC,uvAC intra: 51.4% 56.9% 45.5% inter: 14.9% 20.7% 8.5%
# [libx264 @ 0x55d03591a040] i16 v,h,dc,p: 93%  2%  3%  1%
# [libx264 @ 0x55d03591a040] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 29% 10% 24%  4%  6%  8%  5%  8%  6%
# [libx264 @ 0x55d03591a040] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 34% 11% 15%  4%  9% 10%  6%  8%  4%
# [libx264 @ 0x55d03591a040] i8c dc,h,v,p: 60% 11% 24%  5%
# [libx264 @ 0x55d03591a040] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55d03591a040] ref P L0: 54.1% 17.7% 19.7%  8.5%
# [libx264 @ 0x55d03591a040] ref B L0: 89.7%  8.5%  1.7%
# [libx264 @ 0x55d03591a040] ref B L1: 97.0%  3.0%
# [libx264 @ 0x55d03591a040] kb/s:923.87
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/home/chuongh/vm2m/data/vis/website/6_production_id_4880458_2160p/ours_tokens/*.jpg':
#   Duration: 00:00:08.33, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 1920x1080 [SAR 1:1 DAR 16:9], 3 fps, 3 tbr, 3 tbn, 3 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [swscaler @ 0x5644660497c0] deprecated pixel format used, make sure you did set range correctly
# [libx264 @ 0x564465faeb40] using SAR=1/1
# [libx264 @ 0x564465faeb40] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x564465faeb40] profile High, level 4.0, 4:2:0, 8-bit
# [libx264 @ 0x564465faeb40] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=34 lookahead_threads=5 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=3 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/home/chuongh/vm2m/data/vis/website/6_production_id_4880458_2160p/ours_tokens.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1920x1080 [SAR 1:1 DAR 16:9], q=-1--1, 3 fps, 12288 tbn, 3 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   25 fps=0.0 q=-1.0 Lsize=     932kB time=00:00:07.33 bitrate=1041.5kbits/s speed=11.3x
# video:931kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.121018%
# [libx264 @ 0x564465faeb40] frame I:1     Avg QP:10.18  size:112961
# [libx264 @ 0x564465faeb40] frame P:6     Avg QP:13.22  size: 68150
# [libx264 @ 0x564465faeb40] frame B:18    Avg QP:16.47  size: 23947
# [libx264 @ 0x564465faeb40] consecutive B-frames:  4.0%  0.0%  0.0% 96.0%
# [libx264 @ 0x564465faeb40] mb I  I16..4: 47.4% 42.2% 10.5%
# [libx264 @ 0x564465faeb40] mb P  I16..4:  1.6%  9.4%  1.7%  P16..4: 13.2% 12.8%  7.3%  0.0%  0.0%    skip:54.1%
# [libx264 @ 0x564465faeb40] mb B  I16..4:  0.2%  0.9%  0.3%  B16..8: 20.9%  8.5%  2.1%  direct: 3.8%  skip:63.4%  L0:37.3% L1:37.1% BI:25.6%
# [libx264 @ 0x564465faeb40] 8x8 transform intra:57.2% inter:59.0%
# [libx264 @ 0x564465faeb40] coded y,uvDC,uvAC intra: 50.6% 55.7% 43.7% inter: 14.8% 20.1% 8.4%
# [libx264 @ 0x564465faeb40] i16 v,h,dc,p: 93%  2%  4%  1%
# [libx264 @ 0x564465faeb40] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 32% 10% 23%  4%  6%  7%  5%  8%  5%
# [libx264 @ 0x564465faeb40] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 33% 11% 15%  5%  9% 10%  6%  7%  4%
# [libx264 @ 0x564465faeb40] i8c dc,h,v,p: 60% 11% 24%  5%
# [libx264 @ 0x564465faeb40] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x564465faeb40] ref P L0: 54.3% 17.4% 19.6%  8.7%
# [libx264 @ 0x564465faeb40] ref B L0: 90.3%  8.0%  1.7%
# [libx264 @ 0x564465faeb40] ref B L1: 97.4%  2.6%
# [libx264 @ 0x564465faeb40] kb/s:914.79
